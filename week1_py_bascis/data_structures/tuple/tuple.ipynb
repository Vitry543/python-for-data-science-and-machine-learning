# %%
t=('apple','banana','cherry')
print(t)
# Out:
# ('apple', 'banana', 'cherry')

# %%
# single element tuple
t=(1)
print(type(t))
t=(1,)
print(type(t))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
t=('apple')
print(type(t))
t=('apple',)
print(type(t))
# Out:
# <class 'str'>
# <class 'tuple'>

# %%
# accessing tuple
t=(1,2,3,4,5)
print(t)
t[0]
# Out:
# (1, 2, 3, 4, 5)
# 1

# %%
t[-1]
# Out:
# 5

# %%
print(t[1:3])
print(t[::-1])
# Out:
# (2, 3)
# (5, 4, 3, 2, 1)

# %%
# mutable only by converting to list

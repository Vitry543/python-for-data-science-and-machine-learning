# %%
student={'name':'John','age':25,'course':'CS'}
print(student)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS'}

# %%
print(student['name'])
print(student['age'])
# Out:
# John
# 25

# %%
student['grade']='A'
print(student)
student['subject']='Math'
print(student)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'A'}
# {'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'A', 'subject': 'Math'}

# %%
for i, j in student.items():
    print(i,j)
# Out:
# name John
# age 25
# course CS
# grade A
# subject Math

# %%
print(student)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'A', 'subject': 'Math'}

# %%
del student['grade']
print(student)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS', 'subject': 'Math'}

# %%
student.get('grade')
student.get('grade', 'Not Found')
# Out:
# 'Not Found'

# %%
student.pop('age')
print(student)
# Out:
# {'name': 'John', 'course': 'CS', 'subject': 'Math'}

# %%
# iteration
student={'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'A', 'subject': 'Math'}
for key,value in student.items():
    print(key,value)
# Out:
# name John
# age 25
# course CS
# grade A
# subject Math

# %%
# manipulating dictionaries
person={'name':'John','age':25,'course':'CS','grade':'A','subject':'Math'}
print(person)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'A', 'subject': 'Math'}

# %%
student['grade']='b'
print(person)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'b', 'subject': 'Math'}

# %%
student['mail']='@mail.com'
print(student)
# Out:
# {'name': 'John', 'age': 25, 'course': 'CS', 'grade': 'b', 'subject': 'Math', 'mail': '@mail.com'}

# %%
student['age']='30'
print(student)
# Out:
# {'name': 'John', 'age': '30', 'course': 'CS', 'grade': 'b', 'subject': 'Math', 'mail': '@mail.com'}

# %%
if 'grade' in student:
    del
# Out:
# b
